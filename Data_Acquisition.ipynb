# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import webbrowser
import requests

import re

# %%
from docx import Document
document=Document("resumes/carlos_Resume.docx")
import docx2txt
#file= input('enter resume: ')
#doc = [docx2txt.process('/Users/musubimanagement/Desktop/Resume_screening/resumes/Jevon resume.docx')]

# %%
#doc

# %%
#field=[]
#resume=[]
#field.append(branch)
#resume.append(doc)

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data.to_csv('resume.csv')

# %%
df=pd.read_csv('resume.csv')

# %%
df.head()

# %%
import os
p=[]
for root, dirs, files in os.walk(os.path.abspath("")):
    print(files)
    #for file in files:
    #    print(file)
        #print(os.path.join(root, file))
        #p.append(os.path.join(root, file))

# %%
os.walk(os.path.abspath("/resumes"))

# %%
p[0]

# %%
p[1]

# %%
f=pd.DataFrame(columns=["Resume"])
field=[]
resume=[]
for i in len(p):
    doc = docx2txt.process(p[i])
    #field.append(branch)
    resume.append(doc)

# %%
resume=[]
i=0
while i<10:
    print(docx2txt.process(p[i]))
    
    #field.append(branch)
    #resume.append(doc)
    i=i+1

   # print(resume)

# %%
def split_string():
    doc = docx2txt.process('resumes/fadhila resume.docx')
    import string
    global tesxt_list
    res = re.sub('['+string.punctuation+']', '', doc).split()
    return res

# %%
split_string()
# Out:
# ['Fadhila',
#  'Yousuf',
#  'Data',
#  'Scientist',
#  'LinkedIn',
#  'httpslinkedincominfadhilayosof',
#  'GitHub',
#  'httpsgithubcomfadhilayosof',
#  'Portfolio',
#  'httpsfadhilayosofgithubioPortfolio',
#  '4429',
#  'count',
#  'ct',
#  'sterling',
#  'Heights',
#  'MI',
#  '48310',
#  'Cell',
#  'no',
#  '5867189379',
#  'fmyosofmtuedu',
#  'PROJECTS',
#  'Identifying',
#  'Symptoms',
#  'of',
#  'Orthopedic',
#  'Patients',
#  'as',
#  'Normal',
#  'or',
#  'AbnormalClassification',
#  'Problem',
#  'Skills',
#  'used',
#  'Python',
#  'Pandas',
#  'sklearn',
#  'Matplotlib',
#  'Project',
#  'Objective',
#  'Classifying',
#  'Biomechanical',
#  'Features',
#  'of',
#  'Orthopedic',
#  'Patients',
#  'based',
#  'on',
#  'provided',
#  'features',
#  'to',
#  'decrease',
#  'the',
#  'time',
#  'required',
#  'for',
#  'diagnosis',
#  'Quantifiable',
#  'result',
#  'We',
#  'could',
#  'classify',
#  'the',
#  'type',
#  'of',
#  'tumour',
#  'resulting',
#  'in',
#  '85',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c93acdd50369> in <module>
# ----> 1 string.punctuation
#
# NameError: name 'string' is not defined
